# %% [markdown]
# This notebook visualizes the trajectory tracking with the trunk system.
#
# Additionally to the point mass model, initial trials included using a chain with less links, but the same total lengths. This functionality is still part of the TrunkMPC2D class.
#
# Change model schedules and step sizes and observed tracking performance: \
# n: List of used chain models, for instance [16, 8, 'p'] means that we have three phases switching from the 16 link model to the 8 link model and then to the point mass model. \
# dt: list of integration step sizes \
# N_list: determines the number of shooting intervals in each phase for instance [10,10,10] means that all three models are used for 10 shooting intervals each. \ \
#
# The trajectory considered in the paper is loaded. A new trajectory_name can be created with Trajectory_finding_script, the user can select points the trajectory is supposed to go through, then a spline is fitted through these points to create a reference trajectory to track for the MPC. \ \
#
# Additional settings determine for example if the system is simulated with an acados simulator or in mujoco.

# %%
import mujoco
import numpy as np
import os
from trunk.trunk_mpc_2d_acados import TrunkMPC2DEETracking, TrunkMPC2DOptions
import casadi as ca
import matplotlib.pyplot as plt
from trunk.archive.Trajectory_finding_script import select_periodic_trajectory
from trunk.trajectory_tracking_trunk_closed_loop import closed_loop_ee_tracking_mujoco, closed_loop_ee_tracking_acados
from trunk.trunk_utils import get_x_and_y_pos
from plotting_utils_shared import latexify_plot
from utils_shared import get_dir

# %% [markdown]
# Settings.

# %%
n = [8, 4, 'p'] # Use 8 link model
N_list = [10, 10, 10]
n_high = 8 # system for simulation, should be set to the initial n value
nlp_solver_type = 'SQP'

# noise options during closed loop sim, only works with mujoco sim
perturbation_variance = 0.0
controller_interval = 0.005

trunk_mpc_2d_options = TrunkMPC2DOptions(n=n, dt=controller_interval, N_list=N_list,n_high=n_high, nlp_solver_type=nlp_solver_type, ub_x_ee = [0.2, 1e15], lb_x_ee = [-1e15, -1e15]) #0.2 before 

current_dir = get_dir("src/trunk")
xml_path = os.path.join(current_dir, "archive", "models_mujoco", f"chain_{n_high}_links_expanded.xml")
Mjmodel = mujoco.MjModel.from_xml_path(xml_path)
Mjmodel.opt.timestep = 0.001  # Set timestep to 1 ms (500 Hz simulation frequency)
Mjdata = mujoco.MjData(Mjmodel)

# settings regarding reference trajectory
trajectory_name = "trajectory_oval" # "trajectory_new" if new trajectory is created with the trajectory finding script
frequency = 1.0 # frequency with which the reference trajectory is considered

# Closed-loop sim settings
duration = 10.0  # (seconds)
use_mujoco = False # decides if mujoco odr acados is used for closed loop sim

# Plotting and videos
create_video = False
framerate = 60  # (Hz) Video framerate
plot_open_loop_plan_bool = True # Activate to visualize the open loop plans during simulation
plot_configs = True

# %% [markdown]
# Setup and closed-loop sim.

# %%
Phi_t_func, Phi_dot_t_func = select_periodic_trajectory(n=n[0], frequency=frequency, trajectory_name=trajectory_name, plot=False)

# evaluate one period for plotting
T = 1 / frequency  # Period of the motion
time_steps = np.linspace(0, T, 100)  # 100 time steps within one period

# Evaluate the trajectory using Phi_t_func
trajectory = np.array([Phi_t_func(t_val) for t_val in time_steps])

# Extract x and z coordinates
trajectory_x = trajectory[:, 0]  # x-coordinates
trajectory_z = trajectory[:, 1]  # z-coordinates

# initialize MPC
trunkMPC = TrunkMPC2DEETracking(Phi_t_func, Phi_dot_t_func, trunk_mpc_2d_options)
# Out:
# Loading trajectory from /home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/src/trunk/trajectories_ee_tracking/trajectory_oval.pkl...
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# WARNING: set_phase: Phase 0 contains non-default solver options: ['integrator_type'], which will be ignored.
#  Solver options need to be set via AcadosMultiphaseOcp.solver_options or mocp_opts instead.
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# WARNING: set_phase: Phase 2 contains non-default solver options: ['integrator_type'], which will be ignored.
#  Solver options need to be set via AcadosMultiphaseOcp.solver_options or mocp_opts instead.
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_min is deprecated and has new name: globalization_alpha_min
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option alpha_reduction is deprecated and has new name: globalization_alpha_reduction
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option eps_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option full_step_dual is deprecated and has new name: globalization_full_step_dual
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option line_search_use_sufficient_descent is deprecated and has new name: globalization_line_search_use_sufficient_descent
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# The option nlp_solver_step_length is deprecated and has new name: globalization_fixed_step_length
# Phase 0 contains non-default terminal fields: ['W_e', 'cost_type_e', 'yref_e', 'lh_e', 'uh_e', 'con_h_expr_e', 'cost_y_expr_e'], which will be ignored.
# Calling make_consistent for phase 0.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Calling make_consistent for phase 1.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Phase 2 contains non-default terminal fields: ['W_e', 'cost_type_e', 'yref_e', 'lh_e', 'uh_e', 'con_h_expr_e', 'cost_y_expr_e'], which will be ignored.
# Calling make_consistent for phase 2.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Calling make_consistent for phase 3.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Calling make_consistent for phase 4.
#
# WARNING: Gauss-Newton Hessian approximation with EXTERNAL cost type not well defined!
# got cost_type EXTERNAL for cost_type_e, hessian_approx: 'GAUSS_NEWTON'.
# With this setting, acados will proceed computing the exact Hessian for the cost term and no Hessian contribution from constraints and dynamics.
# If the external cost is a linear least squares cost, this coincides with the Gauss-Newton Hessian.
# Note: There is also the option to use the external cost module with a numerical Hessian approximation (see `ext_cost_num_hess`).
# OR the option to provide a symbolic custom Hessian approximation (see `cost_expr_ext_cost_custom_hess`).
#
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# rendered model templates successfully
#
# mocp_render_templates: rendered solver templates successfully!
#
# rm -f libacados_ocp_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.so
# rm -f model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun_jac_ut_xt.o acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.o
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun_jac_ut_xt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun_jac_uxt_zt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun_jac_ut_xt.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.o acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.c
# acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.c: In function ‘multiphase_ocp_10_1_10_1_10_20251229_041705_024483_acados_create_with_discretization’:
# acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.c:1758:25: warning: too many arguments for format [-Wformat-extra-args]
#  1758 |         fprintf(stderr, "multiphase_ocp_10_1_10_1_10_20251229_041705_024483_acados_create_with_discretization: new_time_steps should be NULL " \
#       |                         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun_jac.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun_jac.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun_jac.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_dyn_disc_phi_fun_jac.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_ode_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_ode_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_vde_forw.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_vde_forw.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_vde_adj.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_expl_vde_adj.c
# cc -shared model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_8_4_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/model_4_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/transition_model_point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_0_fun_jac_ut_xt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun_jac_uxt_zt.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constraints/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_constr_h_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun.o point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost/point_mass_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_cost_y_e_fun_jac_ut_xt.o acados_solver_multiphase_ocp_10_1_10_1_10_20251229_041705_024483.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FUL ...
# -L -l
# acados was compiled without OpenMP.
# Warning: Please note that the following versions of CasADi are officially supported: 3.4.0 or 3.4.5 or 3.5.1 or 3.5.2 or 3.5.3 or 3.5.4 or 3.5.6 or 3.5.5 or 3.6.0 or 3.6.1 or 3.6.2 or 3.6.3 or 3.6.4 or 3.6.5 or 3.6.6 or 3.6.7.
#  If there is an incompatibility with the CasADi generated code, please consider changing your CasADi version.
# Version 3.7.0 currently in use.
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o acados_sim_solver_model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM.o acados_sim_solver_model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u_z.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u.c
# cc -fPIC -std=c99   -O2 -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/acados -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/blasfeo/include -I/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/include/hpipm/include  -c -o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.c
# cc -shared acados_sim_solver_model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u_z.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_fun_jac_x_xdot_u.o model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_model/model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM_impl_dae_jac_x_xdot_u_z.o -o libacados_sim_solver_model_8_links_8_4_p_10_10_10_015000000000000005_FULL_CONDENSING_HPIPM.so -L/home/lukas/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/acados/lib -lacados -lhpipm -lblasfeo -lm
# acados was compiled without OpenMP.

# %%
# Simulate and save video (if create_video and use_mujoco).
ee_site_id = mujoco.mj_name2id(Mjmodel, mujoco.mjtObj.mjOBJ_SITE, "endeffector")

if use_mujoco:
    control_inputs, ee_pos, costs, _, _, _ = closed_loop_ee_tracking_mujoco(n, n_high, Mjmodel, Mjdata, duration, framerate, create_video, plot_open_loop_plan_bool, trajectory_x, trajectory_z, trunkMPC, controller_interval = controller_interval, perturbation_variance=perturbation_variance)
    print(f"Mean_costs:{np.mean(costs)}")
else:
    control_inputs, states, _, ee_pos, costs, _, _, _ = closed_loop_ee_tracking_acados(n, n_high, duration, plot_open_loop_plan_bool, trajectory_x, trajectory_z, trunkMPC)
    print(f"Mean_costs:{np.mean(costs)}")

print('Simulation done with n:', n)
# Out:
# computation time: 0.010107
# computation time: 0.003614
# computation time: 0.005203
# computation time: 0.004875
# computation time: 0.004836
# computation time: 0.00363
# computation time: 0.005088
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       6     print(f"Mean_costs:{np.mean(costs)}")
#       7 else:
# ----> 8     control_inputs, states, _, ee_pos, costs, _, _, _ = closed_loop_ee_tracking_acados(n, n_high, duration, plot_open_loop_plan_bool, trajectory_x, trajectory_z, trunkMPC)
#       9     print(f"Mean_costs:{np.mean(costs)}")
#      11 print('Simulation done with n:', n)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/src/trunk/trajectory_tracking_trunk_closed_loop.py:198, in closed_loop_ee_tracking_acados(n, n_high, duration, plot_open_loop_plan_bool, trajectory_x, trajectory_z, trunkMPC, sim_solver)
#     196 if step % 250 == 0 and plot_open_loop_plan_bool:
#     197     print("computation time:", solve_time_tot)
# --> 198     plot_open_loop_plan_ee(trunkMPC, trajectory_x, trajectory_z, n_high, None, ground_truth_mujoco=False)
#     200 # compute costs
#     201 if trunkMPC.multi_phase:
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/src/trunk/plotting_utils_trajectory_tracking.py:162, in plot_open_loop_plan_ee(trunkMPC, circle_x, circle_z, n_high, ee_side_id, ground_truth_mujoco, mjData, mjModel)
#     160 plt.legend()
#     161 plt.grid()
# --> 162 plt.show()
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/pyplot.py:614, in show(*args, **kwargs)
#     570 """
#     571 Display all open figures.
#     572
#    (...)
#     611 explicitly there.
#     612 """
#     613 _warn_if_gui_out_of_main_thread()
# --> 614 return _get_backend_mod().show(*args, **kwargs)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure),
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/backend_bases.py:2158, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2156 if bbox_inches:
#    2157     if bbox_inches == "tight":
# -> 2158         bbox_inches = self.figure.get_tightbbox(
#    2159             renderer, bbox_extra_artists=bbox_extra_artists)
#    2160         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2161                 pad_inches == "layout"):
#    2162             h_pad = layout_engine.get()["h_pad"]
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/figure.py:1848, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1844 if ax.get_visible():
#    1845     # some Axes don't take the bbox_extra_artists kwarg so we
#    1846     # need this conditional....
#    1847     try:
# -> 1848         bbox = ax.get_tightbbox(
#    1849             renderer, bbox_extra_artists=bbox_extra_artists)
#    1850     except TypeError:
#    1851         bbox = ax.get_tightbbox(renderer)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/axes/_base.py:4574, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4572 bbox_artists = bbox_extra_artists
#    4573 if bbox_artists is None:
# -> 4574     bbox_artists = self.get_default_bbox_extra_artists()
#    4576 for a in bbox_artists:
#    4577     bbox = a.get_tightbbox(renderer)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/axes/_base.py:4495, in _AxesBase.get_default_bbox_extra_artists(self)
#    4490 # always include types that do not internally implement clipping
#    4491 # to Axes. may have clip_on set to True and clip_box equivalent
#    4492 # to ax.bbox but then ignore these properties during draws.
#    4493 noclip = (_AxesBase, maxis.Axis,
#    4494           offsetbox.AnnotationBbox, offsetbox.OffsetBox)
# -> 4495 return [a for a in artists if a.get_visible() and a.get_in_layout()
#    4496         and (isinstance(a, noclip) or not a._fully_clipped_to_axes())]
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/axes/_base.py:4496, in <listcomp>(.0)
#    4490 # always include types that do not internally implement clipping
#    4491 # to Axes. may have clip_on set to True and clip_box equivalent
#    4492 # to ax.bbox but then ignore these properties during draws.
#    4493 noclip = (_AxesBase, maxis.Axis,
#    4494           offsetbox.AnnotationBbox, offsetbox.OffsetBox)
#    4495 return [a for a in artists if a.get_visible() and a.get_in_layout()
# -> 4496         and (isinstance(a, noclip) or not a._fully_clipped_to_axes())]
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/artist.py:891, in Artist._fully_clipped_to_axes(self)
#     885 clip_box = self.get_clip_box()
#     886 clip_path = self.get_clip_path()
#     887 return (self.axes is not None
#     888         and self.get_clip_on()
#     889         and (clip_box is not None or clip_path is not None)
#     890         and (clip_box is None
# --> 891              or np.all(clip_box.extents == self.axes.bbox.extents))
#     892         and (clip_path is None
#     893              or isinstance(clip_path, TransformedPatchPath)
#     894              and clip_path._patch is self.axes.patch))
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:374, in BboxBase.extents(self)
#     371 @property
#     372 def extents(self):
#     373     """Return (:attr:`x0`, :attr:`y0`, :attr:`x1`, :attr:`y1`)."""
# --> 374     return self.get_points().flatten()
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:1115, in TransformedBbox.get_points(self)
#    1111 p = self._bbox.get_points()
#    1112 # Transform all four points, then make a new bounding box
#    1113 # from the result, taking care to make the orientation the
#    1114 # same.
# -> 1115 points = self._transform.transform(
#    1116     [[p[0, 0], p[0, 1]],
#    1117      [p[1, 0], p[0, 1]],
#    1118      [p[0, 0], p[1, 1]],
#    1119      [p[1, 0], p[1, 1]]])
#    1120 points = np.ma.filled(points, 0.0)
#    1122 xs = min(points[:, 0]), max(points[:, 0])
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:2410, in CompositeGenericTransform.transform_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
# -> 2410     return self.get_affine().transform(values)
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:2437, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
#    2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2437                            self._a.get_affine().get_matrix()))
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# File ~/ETH_Zuerich/ASL_Stanford_Masterthesis/Workspace/fading_fidelity_MPC/venv_try_requirements/lib/python3.10/site-packages/matplotlib/transforms.py:1926, in Affine2D.get_matrix(self)
#    1914     """
#    1915     Create a new Affine2D instance from the given values::
#    1916
#    (...)
#    1921     .
#    1922     """
#    1923     return Affine2D(
#    1924         np.array([a, c, e, b, d, f, 0.0, 0.0, 1.0], float).reshape((3, 3)))
# -> 1926 def get_matrix(self):
#    1927     """
#    1928     Get the underlying transformation matrix as a 3x3 array::
#    1929
#    (...)
#    1934     .
#    1935     """
#    1936     if self._invalid:
#
# KeyboardInterrupt:

# %% [markdown]
# Visualize the results.

# %%
# Convert endeffector position to numpy array for plotting
ee_pos = np.array(ee_pos)

# Extract time, x, and z positions
time = np.linspace(0, duration, len(ee_pos))
if use_mujoco:
    x_positions = ee_pos[:, 0]
    z_positions = ee_pos[:, 2]
else:
    x_positions = ee_pos[:, 0]
    z_positions = ee_pos[:, 1] 

# Plot x and z end-effector positions over time
plt.figure()
plt.plot(time, x_positions, label='x-position')
plt.plot(time, z_positions, label='z-position')
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')
plt.title('End-Effector Position Over Time')
plt.legend()
plt.grid()
plt.show()


latexify_plot(fontsize=16)
plt.figure(figsize=(8, 6))

# Plot trunk configurations along trajectory
if not use_mujoco: # states array currently not available with mujoco
    states_array = np.array(states)
    #q_values_first_iteration = states_array[int(1/controller_interval), :n[0]] # q values in first iteration
    link_length = 0.5/n[0]

    # Now plot chain configurations in grey along the trajectory
    if plot_configs:
        num_steps = states_array.shape[0]
        step = 40

        # Plot each chain configuration in grey (no label here)
        for i in range(step, int(1/controller_interval) + step, step):
            angles = states_array[i, :n[0]]
            x_chain, y_chain = get_x_and_y_pos(angles, link_length)
            plt.plot(x_chain, y_chain, color='grey', marker='o', linewidth=1, markersize=3)

        # Add a 'dummy' line for the legend
        plt.plot([], [], color='grey', marker='o', linewidth=1, markersize=4, label='Chain Configurations')


# Plot the development of the end-effector in the x-z plane
plt.plot(x_positions, z_positions , color='red', label='Closed-loop Trajectory')
plt.plot([0.2, 0.2], [-0.5, -0.25], color='black', linestyle='--', linewidth=2.0, label='Constraint')

# Add an ellipsoid with parameters a and b around the origin
plt.plot(trajectory_x, trajectory_z, '--', color='green', label='Desired Trajectory')

plt.xlabel('x-position [m]')
plt.ylabel('z-position [m]')
#plt.title('End-Effector Trajectory in x-z Plane')
plt.axis('equal')  # Make the axes equal
plt.xlim([-0.3, 0.3])  # Set the range from -1.0 to 2.0 on the x-axis
plt.legend(loc="upper left")
plt.grid(color='lightgray', linestyle='-', linewidth=0.5)
trunk_plots_dir = get_dir("plots/trunk")
filename_pdf = trunk_plots_dir / "closed_loop_trajectory.pdf"
plt.savefig(filename_pdf, bbox_inches="tight")
filename_pgf = trunk_plots_dir / "closed_loop_trajectory.pgf"
plt.savefig(filename_pgf, bbox_inches="tight")
plt.show()

# Plot control input development
control_inputs = np.array(control_inputs)
time_control = np.linspace(0, duration, len(control_inputs))
plt.figure()
plt.plot(time_control, control_inputs[:, 0], label='Control Input 1')
plt.plot(time_control, control_inputs[:, 1], label='Control Input 2')
plt.xlabel('Time (s)')
plt.ylabel('Control Inputs')
plt.title('Control Input Development Over Time')
plt.legend()
plt.grid()
plt.show()
